# %%
from qiskit import ClassicalRegister, QuantumRegister, QuantumCircuit,transpile
from qiskit_aer import Aer, AerSimulator
import Our_Qiskit_Functions as oq


import numpy as np
import math as m
S_simulator = Aer.backends('statevector_simulator')[0]
M_simulator = Aer.backends('qasm_simulator')[0]

# %%
	
def itera(qc):
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])

    qc.x(k[2])
        
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])

    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])

    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])

    qc.x(k[5])

    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])

    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])

    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])

    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])

    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])

def invitera(qc):
    qc.ccx(l[3],l[4],l[5])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])


    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])

    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])

    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])


    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])

    qc.x(k[5])   

    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])

    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])

    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0]) 

    qc.x(k[2])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])


#what is the uselfulness how do we decide key values - doubt

# %%
from qiskit import *
# %matplotlib inline
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import Aer
from qiskit.visualization import circuit_drawer
from qiskit.visualization import plot_histogram
import Our_Qiskit_Functions as oq

M_simulator = Aer.backends('qasm_simulator')[0]
l=QuantumRegister(6,'l')
k=QuantumRegister(6,'k')  
trg=QuantumRegister(1,'trg')
anc=QuantumRegister(4,'anc')  
c=ClassicalRegister(6,'c')
qc=QuantumCircuit(l,k,trg,anc,c)
#plain text definition
pt=[0,1,1,1,0,1] #plain text
#key superposition
for i in range(6):
    qc.h(k[i])

qc.x(trg[0])#-why?

for j in range(6):
    itera(qc)
    oq.Grover_Oracle([0,1,1,1,1,1],qc, l,trg,anc)
    invitera(qc) #why?
    oq.Grover_Diffusion([0,0,0,0,0,0],qc,k,trg, anc)

for i in range(6):
    qc.measure(k[i],c[i])

job = M_simulator.run(qc, shots=1024)
results = job.result()
counts = results.get_counts(qc)
print("\nTotal count for each key value are:",counts)
plot_histogram(counts)
# Out:
# Total count for each key value are: {'001101': 14, '101010': 9, '001111': 10, '110101': 5, '101101': 9, '110011': 12, '110000': 12, '011000': 21, '010101': 8, '110100': 6, '101110': 16, '001010': 14, '011110': 15, '110010': 6, '101011': 12, '010110': 33, '010111': 13, '010001': 12, '011010': 8, '000010': 9, '111000': 10, '010000': 9, '100110': 11, '111010': 55, '111100': 15, '001000': 19, '101000': 13, '001100': 5, '101100': 24, '100111': 15, '110110': 9, '001001': 10, '001011': 26, '011011': 14, '111111': 9, '100000': 11, '111110': 6, '110111': 11, '011001': 25, '111001': 6, '100001': 7, '001110': 34, '010011': 15, '100100': 14, '010100': 12, '000111': 36, '100011': 14, '011111': 19, '000100': 15, '000110': 13, '000000': 6, '000101': 6, '110001': 14, '011101': 15, '010010': 7, '101111': 12, '011100': 56, '101001': 22, '000011': 21, '100010': 32, '111011': 12, '000001': 16, '100101': 37, '111101': 42}
